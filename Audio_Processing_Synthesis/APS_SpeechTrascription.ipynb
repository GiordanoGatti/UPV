# %% [markdown]
# # Automatic Speech Recognition System
#
# ```
# Audio Processing and synthesis
# Prof. Jose Rieta
# ```

# %%
#importing libraries
import pandas as pd
import librosa as lr
import numpy as np
# !pip install SpeechRecognition --quiet
import speech_recognition as sr

# %% [markdown]
# Database: Audio Corpora, Fala Brasil Group (Universidade Federal do Pará - UFPA)
#
# - https://gitlab.com/fb-audio-corpora/alcaim16k-DVD1de4/-/tree/master/CarolinaMagalhaes_F050?ref_type=heads

# %%
# Mounting google drive in the folder containing the portion of the dataset used
from google.colab import drive
drive.mount('/content/gdrive')
Path = "gdrive/MyDrive/WAVES/UPV/APS/Database/" # You may save the database in you google drive and change this path accordingly
#Path = "gdrive/MyDrive/APS/Database/"
# Out:
# Mounted at /content/gdrive

# %%
Nrec = 500 #number of recordings
df = pd.DataFrame(columns=['Fs', 'Data', 'Sentence']) #creating a dataframe

#loading all files to the dataframe
for k in range (Nrec):
  file_number = str(k).rjust(4, '0') #transforming the integer number into a 4 digit string with 0s to the left
  df.loc[k,'Fs'], df.loc[k,'Data'] = lr.load(Path+'F050-'+file_number+'.wav', sr=None) #assembling the final string and uploading the .wav file
  S = open(Path+'F050-'+file_number+'.txt') #assembling the final string and opening the .txt file
  df.loc[k,'Sentence'] = S.read().replace("\n", "").split(" ") #removing the \n from the string and adding the sentence to the dataframe (word by word)

display(df)
# Out:
#                                                     Fs   Data  \
# 0    [0.00021362305, 0.0007324219, 0.00039672852, 0...  16000
# 1    [0.0015869141, 0.001373291, 0.0014343262, 0.00...  16000
# 2    [0.0007324219, 0.00064086914, 0.0006713867, 0....  16000
# 3    [0.0014953613, 0.0017700195, 0.0014038086, 0.0...  16000
# 4    [0.0008239746, 0.0009765625, 0.00079345703, 0....  16000
# ..                                                 ...    ...
# 495  [-0.0008239746, -0.0010070801, -0.0005187988, ...  16000
# 496  [0.0009460449, 0.0012817383, 0.0010375977, 0.0...  16000
# 497  [-0.0013122559, -0.0017089844, -0.0012817383, ...  16000
# 498  [-0.00048828125, -0.0008239746, -0.0008239746,...  16000
# 499  [-0.0005187988, -0.000579834, -0.00045776367, ...  16000
#
#                                               Sentence
# 0    [pesquisa, é, uma, coisa, que, muda, a, toda, ...
# 1    [no, total, serão, chamados, vinte, e, seis, m...
# 2    [o, número, de, convocados, por, vaga, é, de, ...
# 3    [atualmente, esse, abatimento, é, limitado, a,...
# 4    [sandra, regina, machado, acho, que, ela, enfi...
# ..                                                 ...
# 495  [passava, o, dia, vendendo, comprando, barganh...
# 496  [a, alta, foi, de, três, vírgula, vinte, e, se...
# 497  [o, time, só, caiu, nos, pênaltis, para, a, fr...
# 498  [empresa, que, serve, ao, ministério, da, faze...
# 499  [queria, ficar, mas, não, pude, o, governo, nã...
#
# [500 rows x 3 columns]

# %% [markdown]
# - Converting Digit Numbers into Words

# %%
def number2words_ptbr(number):
  # A dictionary to map digits to words in Portuguese for simple numbers
  comma = ',' in str(number)
  if (comma==False):
    number = int(number)
    number_words_ptbr = {
      0: "zero", 1: "um", 2: "dois", 3: "três", 4: "quatro",
      5: "cinco", 6: "seis", 7: "sete", 8: "oito", 9: "nove",
      10: "dez", 11: "onze", 12: "doze", 13: "treze", 14: "quatorze",
      15: "quinze", 16: "dezesseis", 17: "dezessete", 18: "dezoito", 19: "dezenove",
      20: "vinte", 30: "trinta", 40: "quarenta", 50: "cinquenta",
      60: "sessenta", 70: "setenta", 80: "oitenta", 90: "noventa",
      100: "cem", 200: "duzentos", 300: "trezentos", 400: "quatrocentos",
      500: "quinhentos", 600: "seiscentos", 700: "setecentos", 800: "oitocentos", 900: "novecentos"
    }
    if number < 20: # in portuguese, if the number is lower than 20, its name comes directly
        return number_words_ptbr[number]
    elif number < 100: # for hundreds it needs to be  composed by the amount of hundreds plus "e" and the tens and units
        tens, ones = divmod(number, 10)
        return f"{number_words_ptbr[tens * 10]} e {number_words_ptbr[ones]}" if ones else f"{number_words_ptbr[tens * 10]}"
    elif number < 1000: # for thousands, the placement of the "e" will depend if it has hundreds or not
        hundreds, remainder = divmod(number, 100)
        if remainder == 0:
            return number_words_ptbr[hundreds * 100]
        elif hundreds==1: # there is a name exception for the case of thousands and ONE HUNDRED which is called "cento"
            return f"cento e {number2words_ptbr(remainder)}"
        else:
            return f"{number_words_ptbr[hundreds * 100]} e {number2words_ptbr(remainder)}"
    elif number < 1000000: # in the case of millions (which will be the last addressed), it will depend on the format of all the lower magnitude digits
        thousands, remainder = divmod(number, 1000)
        thousands_word = "mil" if thousands == 1 else f"{number2words_ptbr(thousands)} mil"
        if remainder == 0:
            return thousands_word
        elif remainder%100==0 or remainder<100:
            return f"{thousands_word} e {number2words_ptbr(remainder)}"
        else:
            return f"{thousands_word} {number2words_ptbr(remainder)}"
    else:
        millions, remainder = divmod(number, 1000000)
        millions_word = "um milhão" if millions == 1 else f"{number2words_ptbr(millions)} milhões"
        if remainder == 0:
            return millions_word
        else:
            return f"{millions_word} {number2words_ptbr(remainder)}"
  else:
    inte = int(number.split(',')[0])
    dec = int(number.split(',')[1])
    return f"{number2words_ptbr(inte)} vírgula {number2words_ptbr(dec)}"

# %% [markdown]
# - Google Speech Recognition Engine

# %%
def transcribe_google(audio_path):
    # Initialize recognizer
    recognizer = sr.Recognizer()

    # Convert audio to audio source for recognition
    with sr.AudioFile(audio_path) as source:
        audio_data = recognizer.record(source)

    # Transcribe audio to text
    try:
        transcription = recognizer.recognize_google(audio_data,language="pt-BR")
        transcription = transcription.lower()

        # Convert numbers to words
        words = transcription.split()
        final_sentence=[]
        for word in words:
          if word.isdigit() or (',' in word and not '%' in word): # handle number convention for
            final_sentence.append(number2words_ptbr(word))
          elif word.endswith("%"):
            # Handle percentage, "50%" -> "cinquenta por cento"
            number_part = word.rstrip("%")
            final_sentence.append(f"{number2words_ptbr(number_part)} por cento")
          elif '.' in word:
            number_split = word.split(".")
            number_part = ''.join(number_split)
            final_sentence.append(f"{number2words_ptbr(number_part)} por cento")
          else:
            final_sentence.append(word)
          transcription_corrected = ' '.join(final_sentence)
        return transcription_corrected

    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
        return
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))
        return

# %%
# Transcribing sentence by sentence
gsent = []
for k in range (Nrec):
  file_number = str(k).rjust(4, '0') #transforming the integer number into a 4 digit string with 0s to the left
  gsent.append(transcribe_google(Path+'F050-'+file_number+'.wav'))
display(gsent)
# Out:
# ['pesquisa é uma coisa que muda a toda hora',
#  'no total serão chamados vinte e seis mil por cento candidatos',
#  'o número de convocados por vaga é de doze candidatos',
#  'atualmente esse abatimento é limitado a setenta por cento dos gastos',
#  'sandra regina machado acho que ela enfim criou o juízo',
#  'eles estão colocando armadilhas nas fazendas onde já ocorreram os ataques',
#  'dessas somente umas trezentos e vinte foram inauguradas em território americano',
#  'no total sete mísseis foram disparados contra o encrave',
#  'em florianópolis foi registrado dois graus celsus na manhã de domingo',
#  'as situações ditas embaraçosas são resolvidas com os dados',
#  'itamar tem razão de estar exultante como nunca desde que virou presidente',
#  'a mãe de todas as reformas é a reforma política',
#  'conseguiram eliminar áreas supérfluas ou que antes eram desperdiçadas',
#  'uma lata de leite em pó integral vale o ingresso',
#  'a maioria dos passageiros do barco naufragado era de crianças',
#  'a provável causa do acidente foi excesso de lotação a bordo',
#  'não prometo nada porque não adianta eu prometer e não cumprir',
#  'se for eleito vocês vão ver o meu trabalho',
#  'ele era um dos poucos atores negros que tinham espaço',
#  'a secretaria estadual de saúde distribuirá cem mil por cento preservativos no carnaval',
#  'são essas qualidades que inspiraram o plano real desde a sua criação',
#  'todos os batizados são consagrados a deus e devem entender a santidade',
#  'o homem sem qualidades não é um livro com',
#  'os problemas surgem nas importações diretas via catálogos por exemplo',
#  'lula chegou ao rio com duas horas de atraso',
#  'no ano a taxa é de três vírgula sete por cento',
#  'batizado de heitor o trabalho traz treze faixas compostas pelo guitarrista',
#  'já viola levou o terceiro cartão amarelo domingo passado',
#  'inflação volta a subir no rio e em são paulo',
#  'cinco frequentemente responde perguntas antes que elas sejam concluídas',
#  'quero estar no grupo e ajudar sempre que necessário',
#  'expedito andrelino de souza cinquenta e um anos encarregado de almoxarifado',
#  'isso mostra que nossa flutuação cambial suja e voluntariosa foi apenas tolice',
#  'nós somos uma espécie de contingência escolhido do povo brasileiro',
#  'não é o primeiro carregamento de armas para angola',
#  'o dinheiro para pagamento dos policiais militares sairia de verba da prefeitura',
#  'até agora na televisão ele já somam quatro ministros',
#  'pode ser o início de uma campanha de contestação da vitória',
#  'da mesma forma empataram nas finalizações um a um',
#  'o jogador do palmeiras foi o único que lançou três vezes',
#  'quanto ao seu próprio time o diagnóstico é menos generoso',
#  'não há desculpas para o mau jogo que fizemos contra arábia',
#  'salário real médio do varejo aumenta doze por cento no mês passado',
#  'em tóquio o dólar fechou cotado a noventa e oito ienes',
#  'os sobreviventes clamaram seus mortos e procuram reconstruir suas vidas',
#  'os dois times perderam uma chance e atrás da outra',
#  'a geração de zinco não seria campeã do mundo',
#  'o curso é gratuito e tem a duração de seis meses',
#  'assaltava desde os oito anos e meus amigos estão quase todos presos',
#  'o mercado de ações vive momentos de plena euforia',
#  'a imprensa não se incomodou nem denunciou esse detalhe',
#  'primeiro arredondou a idade do percussionista para cinquenta anos',
#  'os médicos ainda não sabem quanto tempo ele deverá ficar no hospital',
#  'o feminino fica em quarto sua melhor colocação em olimpíadas',
#  'o modelo foi reestilizado e ganhou linhas mais agressivas',
#  'seu interior no entanto lembra ou de automóvel em japoneses',
#  'sete membros do grupo que se opõem a paz continuam presos',
#  'os jogadores reclamam do calor que consideram excessivo dentro do estádio',
#  'o limite anterior para esses títulos bancários era de noventa dias',
#  'também prepara uma transição para o real no caso das aplicações financeiras',
#  'algumas coisas que não podem deixar de serem vistas em paris',
#  'a demanda por real não por dólar cuja cotação cai',
#  'a cento e setenta bilhões de moedas de um centavo em circulação',
#  'cada uma delas custa oito décimos de um centavo',
#  'o mercado fica de alto risco a curto prazo',
#  'a perspectiva continua otimista para o médio e longo prazos',
#  'o desafio agora é controlar com medicamentos essa secreção',
#  'o jogo contra a suécia deixou todo o país preocupado',
#  'está instalado na casa do avô de lúcia flecha de lima',
#  'funcionários do governo do estado dão orientação técnica aos voluntários',
#  'o ministério diz que não foi consultado sobre a transação',
#  'este ano a empresa deve perder cerca de sete milhões de dólares',
#  'ela começou a tirar fotos ontem em buenos aires',
#  'ele se comprometeu a ler e responder parte da minha correspondência',
#  'os brasileiros no exterior ganharam o poder aquisitivo sem precedentes',
#  'o objetivo é abordar todas as fases da ópera',
#  'o curso é diário e tem duração de três meses',
#  'os jogadores santistas deixaram o gramado sob várias da torcida',
#  'a torcida voltou a criticar a atual administração e não economizou críticas',
#  'a infraero ainda não sabe em qual dos dois aeroportos alexandre embarcou',
#  'eles têm interesse na redução das taxas nos empréstimos rurais',
#  'ele podia dar explicações práticas para sua preferência por faroestes',
#  'longe dos estúdios também estava longe do controle dos produtores',
#  'conversões pelo dólar turismo a mil seiscentos e oitenta',
#  'o preço do primeiro estágio é de r$ duzentos',
#  'tentou usar a cruz mas era curta para isto',
#  'temos de melhorar a qualidade do ensino especialmente na escola pública',
#  'tenho muita vontade de aprender mas baixo o poder aquisitivo',
#  'taborda pegou as assinaturas na manhã do dia vinte e cinco',
#  'também não são recomendáveis os temas de acidentes de automóveis ou alcoolismo',
#  'para discutir sobre ecologia e projetos para gerações futuras',
#  'um velho trem circula entre os bairros de capivari e abernésia',
#  'gilda portugal gouveia será delegada do ministério da educação em são paulo',
#  'a integração é crucial quando se pensa no mercado externo',
#  'programa criado com ajuda de luxemburgo chega em novembro',
#  'dinamizar tais mercados significa coordenar toda a cadeia da carne',
#  'o resultado é menor do que a soma das aptidões',
#  'o sistema brasileiro se inspirou principalmente no modelo utilizado na frança',
#  'já as cadernetas tem apenas hoje como um bom dia para aplicar',
#  'vivo discreto presidente do palmeiras alberto helena júnior',
#  'nada pior que a aplicação distorcida de uma ideia',
#  'rua padre joão manuel cento e cinquenta e quatro',
#  'a cópia distribuída demonstra que as correções foram feitas às pressas',
#  'os dados são coletados nas juntas comerciais dos estados',
#  'é muito interessante ver as mudanças do estilo das mulheres',
#  'ele está com o relator o juiz célio benevides',
#  'as importações de maçã argentina não preocupam os plantadores',
#  'os laboratórios questionam os cálculos mas não negam aumentos reais',
#  'apesar disso continua ligado ao seu país de origem',
#  'o registro do hospital dizia que ele havia fugido',
#  'várias agências de são paulo oferecem cursos de língua no japão',
#  'juro para capital de giro chega a cento e quarenta por cento ao ano',
#  'o tribuna sugere que o acordo foi lesivo para o governo',
#  'não posso me imaginar trabalhando em algo sempre igual',
#  'o mercosul é um compromisso irreversível do governo brasileiro',
#  'a mamata da alfândega foi cinco vezes mais cara',
#  'chega a secretário da cultura com amplo apoio de intelectuais e artistas',
#  'petista não pode ver orelha de eleitor que dá o maior aluguel',
#  'atenção a partir de sexta estarei no caderno copa noventa e quatro',
#  'pelo menos dezenove pessoas ficaram feridas nos dois ataques',
#  'os manuais serão vendidos do dia dez a vinte de outubro',
#  'a legislação eleitoral em vigor nesses anos vetava contribuições de pessoas jurídicas',
#  'o principal segredo para fazer uma boa salada é caprichar no visual',
#  'no inverno esta variação é menor mas ainda existe',
#  'silêncio custa $9000 ao técnico da romênia',
#  'fiz o que a maioria procurou fazer evitei provocar marola',
#  'uma versão da história de amor de tristão e isolda',
#  'o livro ilustrado por zélia suassuna mulher do autor',
#  'a maior alta foi registrada em salvador de dezoito por cento',
#  'com a anistia voltou à prática política da década de cinquenta',
#  'cristiano tem um excepcional trabalho de luz enquadramento',
#  'o quórum qualificado dificultaria mudanças circunstanciais nos futuros governos',
#  'a cortina exposição a poluição intensa favorece o envelhecimento precoce da pele',
#  'o brasil está representado por uma imensa delegação de duas pessoas',
#  'inclui mais de noventa minutos de vídeo fotos e ilustrações',
#  'nos próximos dias devem ser enviados as outras notificações',
#  'evite correr ao banco para trocar o seu dinheiro',
#  'o cruzeiro real continua valendo até o dia quinze de julho',
#  'há quem garanta que um craque não desaprende a arte de jogar',
#  'o autor argumenta que a medida fere legislação sanitária',
#  'a rua florida sempre foi a grande passarela dos turistas',
#  'isso sem contar os negócios gerados pelo licenciamento de produtos ou franquias',
#  'durante a revista eles mandaram que eu me comportasse como homem',
#  'sou uma pessoa normal e me comporto do jeito que quiser',
#  'é só sair nas ruas que os soldados chegam juntos',
#  'não deixe de entrar na galeria pacífico recém restaurado e reformada',
#  'é preciso reformular o parlamento para que ele possa atender a sociedade',
#  'a ocorrência foi registrada como homicídio culposo não intencional',
#  'na avaliação pelo desempenho individual cada executivo tem cinco metas anuais',
#  'na recepção às vezes falhamos em momentos importantes do jogo',
#  'portuguesa pode terminar hoje jogo inacabado com o santo andré',
#  'o populismo em ação é um dos grandes espetáculos da política',
#  'é a oportunidade para o mercado observar os talentos mais promissores',
#  'os maridos não tem reclamações a fazer um do outro',
#  'carros afirma que faz de conta que não vê eduardo e oscar',
#  'eduardo diz que não reclama porque se sente o mais querido',
#  'vamos esquecer o passado vamos pensar no presente e no futuro',
#  'o américa está em quinto lugar com vinte e seis pontos',
#  'o próprio fundo de ações retém o imposto eventualmente devido no resgate',
#  'a classe média paulistana vai às lojas nesse natal com mais apetite',
#  'em grande fase é a nova sensação do time',
#  'os jornais tem aberto enorme espaço aos vários tipos de roubalheira',
#  'grandes empresas começam a investir maciçamente em seu jovens',
#  'no entanto medidas de segurança muito mais rigorosas deverão ser adotadas',
#  'algumas oficinas de parceiros da mata atlântica estão sendo chamadas de estações',
#  'para participar dessas atividades é preciso se inscrever',
#  'costuma-se dizer que não se pode discutir com a vitória',
#  'faltam exatas duas semanas para que comece de fato a corrida eleitoral',
#  'parece o covas beijando covas ou a herondina beijando a herondina',
#  'diz que ele levanta a bíblia o tempo todo na televisão',
#  'o time de jair pereira não conseguia criar oportunidades de gol',
#  'respondeu que a sua frase havia sido tirada do contexto',
#  'sou doce de coração a paz é que me importa',
#  'na universidade de paris três é só isso que se faz',
#  'é porque falo do que é real enquanto os outros',
#  'a coreia exporta um bilhão de dólares em imóveis por ano',
#  'ainda não apareceu um desgraçado aqui para montar um polo moveleiro',
#  'o governo do rio não terá representante no encontro',
#  'o conceito ainda soa meio estranho para o brasileiro',
#  'a polícia prendeu nos últimos vinte dias sessenta carros a seu serviço',
#  'nuno cobra está em fase de revisão do texto',
#  'seu livro deve sair em outubro ou novembro desse ano',
#  'o bebê estava em posição pélvica invertida no interior do útero',
#  'problemas encontrados nos diversos subprocessos organizacionais possuem causas próprias',
#  'ao eliminarmos as causas de um problema automaticamente eliminamos o problema',
#  'dizem que a disciplina é importante e se embriagam as escondidas',
#  'fotógrafo da revista caras quase linchado por querer fotografar os feridos',
#  'as três já pensam em voltar a londres no ano que vem',
#  'a maioria dos times paulistas está bem na competição',
#  'não acho que exista uma resposta única para os problemas das mulheres',
#  'nenhum estava muito entusiasmado e um deles foi claro',
#  'há vários restaurantes que oferecem feijoada carnes e até comida baiana',
#  'é um filme com o impacto vigoroso sobre a vida nacional',
#  'o abatimento vai baixando gradativamente até o final do mês',
#  'a vigilância iniciou um trabalho de combate à doença em dois bairros',
#  'os detentos serão transferidos das delegacias que estiverem lotadas',
#  'as negociações com a áustria continuavam na noite de ontem',
#  'esta tese é motivo de preocupação constante entre os militares',
#  'a festa foi financiada pela indústria de cigarro e se brasa',
#  'durante a festa a empresa lançou a marca de cigarros tetra',
#  'dos duzentos imóveis novos oferecidos no mês apenas quinze foram comercializados',
#  'resta quase um mês para aprovarem sancionar a nova lei',
#  'biscaia jeans regravações podem ligar bicheiros ao tráfico de drogas',
#  'segundo biscaia esses negócios não são relacionados ao jogo do bicho',
#  'apenas dez por cento dos funcionários em todo o brasil trabalharam ontem',
#  'hoje é a autora viva mais estudada nas universidades francesas',
#  'segundo ele foi apenas um almoço rápido entre amigos',
#  'sua densidade teatral ficou prejudicada pelos frequentes intervalos comerciais',
#  'exibido em duas ou três partes renderia muito mais',
#  'estes últimos só podem ser resolvidos com mudanças na constituição',
#  'o envolvimento dos empregados é fundamental para conquistar clientes',
#  'patrocínio rende a cbf vinte e três vírgula seis milhões de dólares',
#  'até mesmo na alemanha a maior parte dos jornais foi muito positiva',
#  'eu acabo de receber uma crítica muito elogiosa aqui no canadá',
#  'é muito raro que algum documentário esteja na lista deles',
#  'no passeio ciro também pode vir em popularidade do colega argentino',
#  'o jornal nacional entrou na história do partido que recebeu o dinheiro sujo',
#  'augusto de toledo tem oitenta e três anos de vida',
#  'nesta partida o lateral da seleção brasileira jorginho contundiu o pé',
#  'abandonou a frança e se fixou em são paulo',
#  'então chegou a hora dessa gente bronzeada mostrar seu valor',
#  'por mais que reze só aparece assombração na minha frente',
#  'concluíram o que é melhor aprofundar o processo do mercosul',
#  'com isso o preço passou para r$ vinte e cinco',
#  'itamar abriu a reunião com uma pergunta de fato pertinente',
#  'a criolita já está em vias de projeto de mineração',
#  'no primeiro e terceiro recusou as ofertas feitas pelos bancos',
#  'o carro rodopiou na pista molhada e bateu no caminhão',
#  'cada um pagou multa de r$ setenta por porte de maconha',
#  'gabriel o pensador é um dos nomes confirmados nessa lista',
#  'só sete por cento na pesquisa se disseram satisfeitos com suas explicações',
#  'dois o piloto teve morte cerebral instantânea no momento do acidente',
#  'seja como for oliveira discorda de joão manuel no ponto',
#  'ela disse que ainda decidirá seu voto para a câmara dos deputados',
#  'o código tributário só permite a indexação dos impostos pela inflação passada',
#  'a latasa vinha solicitando ao governo a adoção da medida',
#  'quem precisar abastecer a geladeira hoje não vai ter tantas dificuldades',
#  'já os supermercados e mercados municipais permanecerão fechados nesta terça-feira',
#  'ele sonha protagonizar a final da copa contra a seleção espanhola',
#  'ele atribuiu o impactos espanhóis a má sorte',
#  'por enquanto os avanços concentram-se na área do reimplante',
#  'existem péssimas edições do livro por isso use o da edição pensamento',
#  'a unidade taxímetro passa a custar oitocentos e setenta cruzeiros reais',
#  'já no dia sete caiu para quarenta e três por cento',
#  'agora o pobre pode ficar com o par completo',
#  'esta espécie de ruído desaparece após uma noite de sono',
#  'vibrações do ar balança uma membrana fazendo a trepidar',
#  'estes ossos captam as vibrações da membrana e balançam',
#  'o trem partiu com setenta e seis passageiros dezenove em cada vagão',
#  'ela tinha de saber que pobre não foi feito para comer biscoito',
#  'segundo ele a polícia não iria ceder a exigências',
#  'dos vinte e um prêmios quatorze foram para trabalhos jornalísticos',
#  'o treino de hoje será das 13:00 às 17:00 em brasília',
#  'só exercitar o quadríceps pode provocar desequilíbrio e forçar mais o joelho',
#  'por isso é importante fortalecer os músculos de trás da coxa',
#  'o travesseiro aromático relaxa combate à insônia e atua como sedativo',
#  'o técnico cláudio duarte fez mudanças no time gaúcho',
#  'o que conta agora é o que o candidato tem a dizer',
#  'não bastará que lula exibir os dentes diante das câmeras',
#  'agora ele despenca do teto em direção ao piso',
#  'esse tempo seria reduzido a metade com as duas urnas',
#  'o novo presidente seria conhecido quatro dias após a votação',
#  'ele disse que o medo do congelamento ainda atrapalha o plano',
#  'fabrício disse que nunca administrou mas também nunca roubou um sorvete',
#  'guimarães rosa o alquimista do coração de josé maria martins',
#  'análise de viés psicológico da obra de guimarães rosa',
#  'os sérvios sempre defenderam a divisão que consolidaria seus ganhos militares',
#  'segundo almeida é praticamente impossível controlar o fogo sem ajuda exterior',
#  'a imagem do terceiro decanato de sagitário é o titã',
#  'eu queria fazer minhas próprias coisas e logo cair na real',
#  'sem texto é impossível interpretar com o mínimo de credibilidade',
#  'os lembretes se tornam meus a medida que os internaliza',
#  'hoje o índio só responde a constituição se solicitar sua emancipação',
#  'daria na ocasião para quitar quase metade do débito',
#  'já dá para comer chocolate sem peso na consciência',
#  'o valor venal dos imóveis vai ser ajustado para realidade',
#  'os países mais avançados vem investindo pesadamente em tecnologias poupadoras de água',
#  'o mercado financeiro só remunera o dinheiro nos dias úteis',
#  'o banco garantia é o mais agressivo participante do mercado financeiro hoje',
#  'veloz nas decisões impiedoso com os adversários joga para matar',
#  'as escolas sozinhas não conseguem informar um bom profissional',
#  'outros produtos também lembrados feijão carne e derivados de soja',
#  'dos dez primeiros apenas a noruega foi eliminado da copa',
#  'os investidores foram para a argentina e para venezuela',
#  'a própria demora no julgamento do processo já incomoda',
#  'o sequestro de bens serviria para garantir o pagamento',
#  'feministas negros e homossexuais fazem reivindicações retrógradas e tendem a exigir privilégios',
#  'a justiça brasileira considerou o fato apenas um crime comum',
#  'a decisão está para ser tomada em fevereiro ou março',
#  'uma ação de molestamento sexual pode levar anos para se concluir',
#  'a bola sai com a equipe que tenta fazer o gol',
#  'a cada sessão barreira se preocupe especificamente com um setor',
#  'a escolha tentou dar o máximo de representatividade aos escolhidos',
#  'xavier descarta hipótese de o caixão ter sido violado',
#  'uma parte importante da nossa vida acaba quando morre alguém querido',
#  'reúne ainda depoimentos de profissionais que já montaram seu próprio negócio',
#  'dinheiro apresentado pelos meios de comunicação como financiamento eleitoral',
#  'as mulheres podem ser lindas perfumadas e adoráveis mesmo',
#  'este parece ser o lema dos franceses ou dos filmes franceses',
#  'tudo parecia segurado diante de visíveis sinais de agonia al',
#  'pode-se optar por comprar cada programa em separado',
#  'isso de que o importante é competir é balela',
#  'posso tirar mais uma semana para trabalhar o time principal',
#  'em setenta e sete todos eles tinham lançado discos',
#  'o brasil tem pressa se o governo está pronto para agir',
#  'nesse instante ouvi meu filho sufocando em seu próprio sangue',
#  'para ele mesmo a carne está sem perspectiva de alta',
#  'o grupo chegou quando os amotinados já tinham saído',
#  'tudo será transparente e gradual fruto de conciliações e consensos',
#  'ele descarta armazéns a céu aberto como ocorreu em oitenta e nove',
#  'é muito importante divulgar a ideia da qualidade para o público',
#  'é uma questão de cidadania que não se restringe a produtos',
#  'a melhoria da qualidade não interessa sua técnicos ou empresários',
#  'nos países desenvolvidos os grandes jornais publicam caderno sobre o tema',
#  'estou muito cheio de pepinos para ficar tratando dos pepinos dos outros',
#  'as pessoas se divertiram tanto que aplaudiram de pé',
#  'é o primeiro contato do grupo com uma produção mais apurada',
#  'na idade média os mapas voltam-se para o leste',
#  'a programação da arte exclui seriados esportes e programas de auditório',
#  'é a maior campanha da empresa realizada até hoje',
#  'o problema é que a inflação demora um pouco para cair',
#  'os pratos são a base de peixe e frutos do mar',
#  'a papel presente aceita encomendas de embalagens até dia vinte',
#  'é muito emocionante os homens se encontrarem à noite no bosque',
#  'no final era um monte de homem se abraçando e chorando',
#  'a pesquisa do datafolha é um levantamento por amostragem estratificada',
#  'a margem de erro é de três pontos percentuais',
#  'pelo acordo israel mantém responsabilidade pela defesa e política externa',
#  'o importante é que tem o entusiasmo para fazer as coisas',
#  'às vezes você pode ter um cargo e não contribuir pois isso nenhuma nenhuma',
#  'a pia batismal de mármore tem dois m de diâmetro',
#  'esse povo tem leis e segredos que só quem é cigano sabe',
#  'visitados todos na ocasião por delegações de grandes empresários',
#  'ontem mais seis exilados voltaram à faixa de gaza',
#  'a paciente de vinte e dois anos passa bem',
#  'o dinheiro é arrecadado pelos templos através do dízimo',
#  'tem-se uma receita mensal de trezentos e quarenta mil por cento',
#  'juliana disse que o banco a ser escolhido é surpresa',
#  'este mês os termômetros descem facilmente abaixo de zero',
#  'vale a pena também fazer uma visita ao museu arqueológico',
#  'dos oitenta e um senadores apenas cinquenta e seis votaram',
#  'a maternidade agora está capacitada para realizar cento e cinquenta partes',
#  'crescem as baixas civis na república separatista de população majoritariamente muçulmana',
#  'esta época de criatividade caiu um pouco no final da década',
#  'o artilheiro viola recebeu na intermediária e avançou para o gol',
#  'o atacante comemorou o gol imitando um diabo símbolo do américa',
#  'uma regra fundamental é definir um limite máximo de consumo',
#  'ela é a pessoa mais mercenária que já conhecia',
#  'o time cometeu vinte e seis faltas durante a partida',
#  'foi o que afirmaram sessenta e dois por cento dos oitocentos entrevistados',
#  'seu desejo é de que apareça logo um doador',
#  'agora continua sendo necessário que a assembleia legislativa aprova o nome',
#  'depois foi a vez do baiano retribuir as homenagens',
#  'se conseguimos uma parte do que ele alcançou será demais',
#  'basta uma vitória para o time se classificar para as semifinais',
#  'os críticos diziam que bastava um dos dois para cumprir esse papel',
#  'o brasil perdeu e puseram nele a culpa pela derrota',
#  'enchimento processo de recuperação evidencia o cuidado com o consumidor',
#  'outro exemplo é a beterraba uma boa alternativa para cenoura',
#  'quem vencia estará classificado para as oitavas de final',
#  'aragão acabou inocentado devido ao baixo número de senadores presentes',
#  'eram necessários quarenta e um votos para aragão perder o mandato',
#  'não estou pensando em voltar para o são paulo',
#  'o parque é considerado uma ilha de tranquilidade em plena avenida paulista',
#  'esta é a opinião de trinta e dois por cento do público',
#  'ele corinthiano afirmou que as 6:00 da tarde iria buscar a namorada',
#  'às vezes numa crise ou numa derrota se aprende mais',
#  'as vendas por catálogo já atingem cinquenta e oito bilhões de dólares',
#  'as estrelas internacionais do violão chegam esta semana a são paulo',
#  'pessoas mais velhas tem pele menos elásticas que os jovens',
#  'eu sou fiel aos meus amigos e eles são fiéis a mim',
#  'os juízes poderão argumentar que na música também é assim',
#  'o jogo foi marcado pela disputa no meio-campo',
#  'no grêmio o meia carlos miguel centralizava o jogo',
#  'o objetivo da ação foi protestar contra o corte ilegal de árvores',
#  'todos os cheques abaixo de $100 são desprezados',
#  'januária nas telas mais uma calúnia do macaco simão',
#  'acertou o alvo em quarenta e três por cento das suas chances',
#  'montados as partes do rosto funcionam como portas de entrada',
#  'ao clicar sobre os olhos você entra nas músicas e videoclipes',
#  'quem sair por último fecha a porta e apague a luz',
#  'a equipe de americana ocupa a oitava posição',
#  'a organização atribuiu os dados ao êxito das campanhas de vacinação',
#  'botafogo e guarani iniciaram a segunda fase com performances semelhantes',
#  'a concentração do bolo de recursos em um pequeno grupo aumentou',
#  'foi definido o campeonato estadual que começa no dia trinta',
#  'o campeonato terá dois turnos nos quais jogam todos contra todos',
#  'classificam-se dois times de cada chave a um quadrangular final',
#  'o vencedor de cada grupo ganha um ponto extra',
#  'o espaço fica portanto vago indisponível para traficante',
#  'os dados são da associação nacional dos fabricantes de veículos automotores',
#  'seus computadores processam até dois milhões de informações por segundo',
#  'casa grande substitui viola e o meia souza fica no banco',
#  'a banda tocou novas músicas enquanto passou pela consolação',
#  'durante todo o ano passado os três tiveram apenas uma falta',
#  'para noventa minutos houve uma revolução debaixo das traves',
#  'o mais desculpável em itamar são os seus vexames de passarela',
#  'para branco este é um jogo como outro qualquer',
#  'até agosto o valor era de sessenta e quatro',
#  'quanto mais avançarmos nas reformas menor será esse anos',
#  'começa hoje em ilhéus o terceiro seminário nacional de turismo ecológico',
#  'eu fui a primeira pessoa a abrir espaço para você',
#  'a última chuva no mato grosso ocorreu em junho',
#  'a nova diretoria tomará posse em primeiro de fevereiro',
#  'o estado registrou redução nos índices de mortalidade infantil',
#  'o plano terá recursos no valor de cento e dezoito mil por cento',
#  'administração é feita pela federação de obras sociais',
#  'os produtos vendidos nestas estantes foram doados por empresas particulares',
#  'o nacional vai ser cauteloso ao enfrentar o são paulo hoje',
#  'dieta para atletas deve ser rica e de fácil digestão',
#  'o estudo é interessante e sofisticado mas suas conclusões são óbvias',
#  'as propostas de política econômica são poucas e imediatas',
#  'eles experimentaram vários tipos de comidas exóticas durante a viagem',
#  'estava muito calor e não soubemos dosar a energia',
#  'nestor pestana duzentos e sessenta e seis região central',
#  'glória funaro já colocou sua coleção de outono-inverno nas prateleiras',
#  'acreditavam que perfeição para o homem era imortalidade',
#  'nossa lua de mel não seria mais a mesma argumenta cíntia',
#  'autoridade palestina libertou ontem quarenta e cinco integrantes',
#  'ficou faltando ainda a devolução do dinheiro da parte aérea',
#  'a grande diferença é que eu estou procurando solidariedade',
#  'as chances que apareciam eram perdidas pelos atacantes cruzeirenses',
#  'a grande virtude da nação brasileira é a tolerância',
#  'turma e serra empatam em trinta e sete por cento',
#  'vou pegar umas cinco macacas do fernando henrique e jogar numa panela',
#  'esta diferença acabou-se refletindo no índice de julho',
#  'o objetivo das imagens é mostrar uma história da evolução do universo',
#  'segundo ele a cabine não faz parte do edifício',
#  'o comitê diz que pagará a taxa de serviço a estas empresas',
#  'a duplicidade se estabelece então como condição do escritor',
#  'isso quer dizer que os estrangeiros não estarão seguros na bósnia',
#  'a principal falha de parreira ocorre no posicionamento dos dois meios ofensivos',
#  'o acordo é voltado inicialmente para a área bancária',
#  'fui para o méxico e fiquei lá três anos',
#  'a permanecer a atual situação será o brasil que não vingará',
#  'só para o curso de inglês é necessário o conhecimento da língua',
#  'o imposto está previsto para vigorar somente até o final deste ano',
#  'ouvir os setecentos e onze pessoas maiores de dezesseis anos',
#  'oitenta por cento desses adolescentes norte-americanos tem um emprego de meio período',
#  'o fato é que estamos no terreno do irreconciliável',
#  'não há obrigatoriedade de intervalo para jornada de trabalho',
#  'almeida informou que a empresa demitiu quarenta funcionários nos últimos vinte dias',
#  'o documento não faz qualquer menção aos custos dos assentamentos',
#  'observar vamos perplexos o vento levar as telhas do galpão',
#  'não se conformam que eles os fatos sejam fatos',
#  'com o debate o velho trabalhista recuperou a velha agressividade',
#  'trata-se do nono subtipo do vírus já identificado no mundo',
#  'a redução entra na necessidade de gerir a consolidação do real',
#  'ana silva dezenove anos está grávida de sete meses',
#  'mais uma vez as chuvas de verão atrapalharam a vida dos paulistanos',
#  'ele é considerado por seus companheiros de tropa como um oficial moderado',
#  'almeida teria sido comunicado que irá deixar o cargo',
#  'ela também afirma que só faz programas com camisinha',
#  'a apuração passou a ser feita antes do sorteio',
#  'para lá se dirigem os refugiados na maioria africanas',
#  'no santo andré a luta é para fugir do rebaixamento',
#  'eles não têm seguro médico e seu futuro é incerto',
#  'como vocês puderam ver na copa faltam atacantes da itália',
#  'na temporada o trânsito na avenida da praia é muito intenso',
#  'eles ganharam as primeiras páginas dos jornais do final da semana passada',
#  'o que aconteceu depois da abertura da bandeira não se sabe',
#  'alguns olhos de lince chegaram a enxergar uma cusparada',
#  'outros ainda nada viram além da abertura da bandeira',
#  'eu não quero e não vou falar sobre câmbio e juros',
#  'na quinta-feira eu já estava indo para vitória jogar',
#  'desta forma os números mais apostados são retirados da disputa',
#  'só se pode ser membro do clube enquanto se é solteiro',
#  'é evidente que este evento é extremamente complexo de se organizar',
#  'ser moderno é ser profissional e não inventar desculpas',
#  'nos desfiles que assisti fizeram o público de idiota',
#  'moda regional só existe se você se isolar do mundo',
#  'o desemprego é particularmente grave para mulheres jovens na espanha',
#  'as cadernetas rendem vinte e oito por cento no dia quinze',
#  'lila covas ainda não sabe o que vai fazer no fundo',
#  'a arte de amar e a metamorfose foram publicadas em roma',
#  'sou uma espécie de amor secreto do povo brasileiro',
#  'basta que sua remuneração não seja menor que r$ setenta',
#  'desde então seu quadro clínico tem deteriorada a cada dia',
#  'flu vai à igreja antes de jogar contra o bahia',
#  'a canção popular é um veículo indiscutível de informação',
#  'esse nosso sintetizador de voz vai ficar uma beleza',
#  'se engana quem pensa que só vale enfeitar presentes normais',
#  'a inflação alta também desestimulou as compras a prazo',
#  'claro que é burrice é maior do que a pedra da gávea',
#  'paulino esperava que a reunião proposta por ele fosse marcada para hoje',
#  'ele acha difícil no entanto que a reunião ocorra',
#  'o corpo fica vermelho vivo à medida que sua temperatura sobe',
#  'às vezes o preso pega fogo especialmente quando transpira muito',
#  'vinte bilhões de dólares já teriam retornado restando quarenta bilhões',
#  'uma exceção foi a crítica de arte lélia coelho frota',
#  'como levava uma vida diferente eram perseguidos onde chegavam',
#  'eles têm razão e se preparam para entrar em greve',
#  'com isso se ampliou o espectro da manipulação genética',
#  'o momento econômico e político deflagrado pelo real é instigante dessa reflexão',
#  'o filme foi lançado pela primeira vez em mil novecentos e setenta',
#  'passava o dia vendendo comprando barganhando com os fregueses',
#  'a alta foi de três vírgula vinte e sete por cento',
#  'o time só caiu nos pênaltis para frança',
#  'empresa que serve o ministério da fazenda aluga comitê aos tucanos',
#  'queria ficar mas não pude o governo não permitia mais']

# %% [markdown]
# - Error Analysis

# %%
wErrorCount = []
aux_list = []
for h in range (Nrec):
  aux = 0
  for o in df["Sentence"][h]:
    if o not in gsent[h]:
      aux=aux+1
  l = len(df["Sentence"][h])
  wErrorCount.append([aux, l, round(aux/l,3)]) # for comparison between the amount of words wront in each sentence and its corresponding percentage
display(wErrorCount)
# Out:
# [[0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [1, 11, 0.091],
#  [0, 9, 0.0],
#  [1, 11, 0.091],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [1, 12, 0.083],
#  [1, 9, 0.111],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [1, 10, 0.1],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [1, 9, 0.111],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 12, 0.0],
#  [0, 12, 0.0],
#  [0, 11, 0.0],
#  [1, 10, 0.1],
#  [0, 9, 0.0],
#  [1, 9, 0.111],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [1, 9, 0.111],
#  [1, 11, 0.091],
#  [0, 11, 0.0],
#  [1, 11, 0.091],
#  [1, 12, 0.083],
#  [1, 12, 0.083],
#  [1, 10, 0.1],
#  [1, 12, 0.083],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [1, 11, 0.091],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [1, 10, 0.1],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [1, 10, 0.1],
#  [0, 12, 0.0],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [1, 10, 0.1],
#  [1, 9, 0.111],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [1, 11, 0.091],
#  [1, 12, 0.083],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [1, 12, 0.083],
#  [2, 9, 0.222],
#  [1, 9, 0.111],
#  [1, 10, 0.1],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 14, 0.0],
#  [1, 11, 0.091],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [1, 12, 0.083],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [3, 9, 0.333],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [1, 9, 0.111],
#  [2, 12, 0.167],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [1, 9, 0.111],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 12, 0.0],
#  [0, 11, 0.0],
#  [1, 9, 0.111],
#  [0, 10, 0.0],
#  [1, 11, 0.091],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [1, 10, 0.1],
#  [1, 12, 0.083],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [1, 12, 0.083],
#  [0, 9, 0.0],
#  [1, 11, 0.091],
#  [1, 9, 0.111],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [0, 8, 0.0],
#  [0, 10, 0.0],
#  [0, 12, 0.0],
#  [2, 12, 0.167],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [1, 11, 0.091],
#  [1, 11, 0.091],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [1, 12, 0.083],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [1, 11, 0.091],
#  [1, 12, 0.083],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [2, 9, 0.222],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [2, 11, 0.182],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [1, 9, 0.111],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [1, 12, 0.083],
#  [0, 12, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [3, 11, 0.273],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [1, 11, 0.091],
#  [1, 10, 0.1],
#  [0, 12, 0.0],
#  [0, 11, 0.0],
#  [1, 10, 0.1],
#  [0, 12, 0.0],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [3, 9, 0.333],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [1, 11, 0.091],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [2, 8, 0.25],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [3, 12, 0.25],
#  [0, 12, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [1, 10, 0.1],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [1, 11, 0.091],
#  [0, 10, 0.0],
#  [3, 10, 0.3],
#  [1, 11, 0.091],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [1, 12, 0.083],
#  [0, 10, 0.0],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [1, 10, 0.1],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [2, 10, 0.2],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [2, 10, 0.2],
#  [0, 8, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 12, 0.0],
#  [1, 11, 0.091],
#  [0, 11, 0.0],
#  [1, 11, 0.091],
#  [1, 11, 0.091],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [1, 11, 0.091],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [1, 11, 0.091],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [1, 10, 0.1],
#  [1, 12, 0.083],
#  [1, 10, 0.1],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [1, 11, 0.091],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [2, 11, 0.182],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [2, 11, 0.182],
#  [0, 11, 0.0],
#  [1, 9, 0.111],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [0, 12, 0.0],
#  [3, 12, 0.25],
#  [0, 10, 0.0],
#  [0, 12, 0.0],
#  [0, 11, 0.0],
#  [1, 10, 0.1],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [2, 9, 0.222],
#  [3, 12, 0.25],
#  [0, 12, 0.0],
#  [1, 10, 0.1],
#  [0, 11, 0.0],
#  [10, 11, 0.909],
#  [0, 8, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [1, 12, 0.083],
#  [0, 10, 0.0],
#  [1, 10, 0.1],
#  [1, 9, 0.111],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [1, 9, 0.111],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [1, 10, 0.1],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [1, 9, 0.111],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [1, 11, 0.091],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [1, 12, 0.083],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [1, 9, 0.111],
#  [1, 12, 0.083],
#  [0, 9, 0.0],
#  [1, 9, 0.111],
#  [0, 12, 0.0],
#  [0, 10, 0.0],
#  [1, 9, 0.111],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [1, 9, 0.111],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 12, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 9, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [1, 10, 0.1],
#  [1, 10, 0.1],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [6, 9, 0.667],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [0, 12, 0.0],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [0, 10, 0.0],
#  [1, 9, 0.111],
#  [0, 10, 0.0],
#  [0, 9, 0.0],
#  [1, 12, 0.083],
#  [0, 12, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 9, 0.0],
#  [0, 11, 0.0],
#  [0, 10, 0.0]]

# %%
auxerror = 0
auxerrort = 0
tErrors=[]
for k in range (len(wErrorCount)):
  auxerror = auxerror+wErrorCount[k][0]
  auxerrort = auxerrort+wErrorCount[k][1]
print(f'Total Error: {round(auxerror/auxerrort,3)*100} %')
# Out:
# Total Error: 2.9000000000000004 %

# %%
mydictionary = []
for j in range(Nrec):
  for g in df.loc[j, "Sentence"]:
    if (len(mydictionary)==0):
      mydictionary.append(g)
    elif (not g in mydictionary):
      mydictionary.append(g)

print(mydictionary)
print(len(mydictionary))
# Out:
# ['pesquisa', 'é', 'uma', 'coisa', 'que', 'muda', 'a', 'toda', 'hora', 'no', 'total', 'serão', 'chamados', 'vinte', 'e', 'seis', 'mil', 'candidatos', 'o', 'número', 'de', 'convocados', 'por', 'vaga', 'doze', 'atualmente', 'esse', 'abatimento', 'limitado', 'setenta', 'cento', 'dos', 'gastos', 'sandra', 'regina', 'machado', 'acho', 'ela', 'enfim', 'criou', 'juízo', 'eles', 'estão', 'colocando', 'armadilhas', 'nas', 'fazendas', 'onde', 'já', 'ocorreram', 'os', 'ataques', 'dessas', 'somente', 'umas', 'trezentas', 'foram', 'inauguradas', 'em', 'território', 'americano', 'sete', 'mísseis', 'disparados', 'contra', 'encrave', 'florianópolis', 'foi', 'registrado', 'dois', 'graus', 'celsius', 'na', 'manhã', 'domingo', 'as', 'situações', 'ditas', 'embaraçosas', 'são', 'resolvidas', 'com', 'dados', 'itamar', 'tem', 'razão', 'estar', 'exultante', 'como', 'nunca', 'desde', 'virou', 'presidente', 'mãe', 'todas', 'reformas', 'reforma', 'política', 'conseguiram', 'eliminar', 'áreas', 'supérfluas', 'ou', 'antes', 'eram', 'desperdiçadas', 'lata', 'leite', 'pó', 'integral', 'vale', 'um', 'ingresso', 'maioria', 'passageiros', 'do', 'barco', 'naufragado', 'era', 'crianças', 'provável', 'causa', 'acidente', 'excesso', 'lotação', 'bordo', 'não', 'prometo', 'nada', 'porque', 'adianta', 'eu', 'prometer', 'cumprir', 'se', 'for', 'eleito', 'vocês', 'vão', 'ver', 'meu', 'trabalho', 'ele', 'poucos', 'atores', 'negros', 'tinham', 'espaço', 'secretaria', 'estadual', 'saúde', 'distribuirá', 'cem', 'preservativos', 'carnaval', 'essas', 'qualidades', 'inspiraram', 'plano', 'real', 'sua', 'criação', 'todos', 'batizados', 'consagrados', 'deus', 'devem', 'tender', 'à', 'santidade', 'homem', 'sem', 'livro', 'comum', 'problemas', 'surgem', 'importações', 'diretas', 'via', 'catálogos', 'exemplo', 'lula', 'chegou', 'ao', 'rio', 'duas', 'horas', 'atraso', 'ano', 'taxa', 'três', 'vírgula', 'batizado', 'heitor', 'traz', 'treze', 'faixas', 'compostas', 'pelo', 'guitarrista', 'viola', 'levou', 'terceiro', 'cartão', 'amarelo', 'passado', 'inflação', 'volta', 'subir', 'paulo', 'cinco', 'frequentemente', 'responde', 'perguntas', 'elas', 'sejam', 'concluídas', 'quero', 'grupo', 'ajudar', 'sempre', 'necessário', 'expedito', 'andrelino', 'souza', 'cinquenta', 'anos', 'encarregado', 'almoxarifado', 'isso', 'mostra', 'nossa', 'flutuação', 'cambial', 'suja', 'voluntariosa', 'apenas', 'tolice', 'nós', 'somos', 'espécie', 'contingente', 'escolhido', 'povo', 'brasileiro', 'primeiro', 'carregamento', 'armas', 'para', 'angola', 'dinheiro', 'pagamento', 'policiais', 'militares', 'sairia', 'verba', 'da', 'prefeitura', 'até', 'agora', 'televisão', 'somam', 'quatro', 'ministros', 'pode', 'ser', 'início', 'campanha', 'contestação', 'vitória', 'mesma', 'forma', 'empataram', 'finalizações', 'jogador', 'palmeiras', 'único', 'lançou', 'vezes', 'quanto', 'seu', 'próprio', 'time', 'diagnóstico', 'menos', 'generoso', 'há', 'desculpas', 'mau', 'jogo', 'fizemos', 'arábia', 'salário', 'médio', 'varejo', 'aumenta', 'mês', 'tóquio', 'dólar', 'fechou', 'cotado', 'noventa', 'oito', 'ienes', 'sobreviventes', 'cremaram', 'seus', 'mortos', 'procuram', 'reconstruir', 'suas', 'vidas', 'times', 'perderam', 'chance', 'atrás', 'outra', 'geração', 'zico', 'seria', 'campeã', 'mundo', 'curso', 'gratuito', 'duração', 'meses', 'assaltava', 'meus', 'amigos', 'quase', 'presos', 'mercado', 'ações', 'vive', 'momentos', 'plena', 'euforia', 'imprensa', 'incomodou', 'nem', 'denunciou', 'detalhe', 'arredondou', 'idade', 'percussionista', 'médicos', 'ainda', 'sabem', 'tempo', 'deverá', 'ficar', 'hospital', 'feminino', 'fica', 'quarto', 'melhor', 'colocação', 'olimpíadas', 'modelo', 'reestilizado', 'ganhou', 'linhas', 'mais', 'agressivas', 'interior', 'entanto', 'lembra', 'automóveis', 'japoneses', 'membros', 'opõe', 'paz', 'continuam', 'jogadores', 'reclamam', 'calor', 'consideram', 'excessivo', 'dentro', 'estádio', 'limite', 'anterior', 'estes', 'títulos', 'bancários', 'dias', 'também', 'preparam', 'transição', 'caso', 'das',  ...
# 2126
